# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JangirSumit/kmeans-clustering/refs/heads/master/driver-data.csv')
df
# Out:
#               id  mean_dist_day  mean_over_speed_perc
# 0     3423311935          71.24                    28
# 1     3423313212          52.53                    25
# 2     3423313724          64.54                    27
# 3     3423311373          55.69                    22
# 4     3423310999          54.58                    25
# ...          ...            ...                   ...
# 3995  3423310685         160.04                    10
# 3996  3423312600         176.17                     5
# 3997  3423312921         170.91                    12
# 3998  3423313630         176.14                     5
# 3999  3423311533         168.03                     9
#
# [4000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['mean_dist_day', 'mean_over_speed_perc']] = scaler.fit_transform(df[['mean_dist_day', 'mean_over_speed_perc']])

# %%
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=10)
k_means.fit(df.drop(columns = 'id'))
# Out:
# KMeans(n_clusters=10)

# %%
import matplotlib.pyplot as plt

labels = k_means.labels_

plt.scatter(df['mean_dist_day'], df['mean_over_speed_perc'], c=labels, cmap='viridis')
plt.xlabel('Mean Distance from Center')
plt.ylabel('Mean Speed')
plt.title('KMeans Clust ering Results')
plt.show()

# %%
k_means.cluster_centers_
# Out:
# array([[ 1.94946647,  0.40140733],
#        [-0.48723321, -0.40246569],
#        [ 1.90172968,  4.40784767],
#        [-0.47952334,  1.57909169],
#        [ 1.952085  , -0.27320345]])

# %%
-k_means.score(df.drop(columns = 'id'), k_means.predict(df.drop(columns = 'id')))
# Out:
# 12.908918966756174
